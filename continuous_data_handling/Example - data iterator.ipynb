# %% [markdown]
# # DAS data iterator
#
# This is a simple example that shows the application of the iterator.

# %% [markdown]
# Let's first download some FORGE data.
# Use this script from your shell to download DAS data into a subfolder called 'Data' (or another name, and change configuration file config_general accordingly). The first and last file are considered invalid, because they cannot be properly buffered, and are thus not plotted.
#
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064823.sgy <br>
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064838.sgy <br>
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064853.sgy <br>
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064908.sgy <br>
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064923.sgy <br>
# wget -q https://pando-rgw01.chpc.utah.edu/silixa_das_apr_26_2019/FORGE_78-32_iDASv3-P11_UTC190426064938.sgy <br>

# %%
import config_general as cfg
import data_streaming as stream
import matplotlib.pyplot as plt

def plot_seismic_horiz(data, dx, dt):
    nch, nt = data.shape
#     plt.figure(figsize=(8,5))
    plt.imshow(data, aspect='auto', cmap='seismic', extent=(0, (nt-1)*dt, (nch-1)*dx, 0))
    plt.ylabel('Depth (m)')
    plt.xlabel('Time (s)')

data_iter = stream.DataIterator(proc_steps=cfg.proc_steps, folder_name=cfg.data_path,
                                    db_name=cfg.events_db_name, output_overlap=cfg.overlap_samples)
plt.close('all')
for curr_chunk in data_iter:
    if curr_chunk.check_validity():
        plot_seismic_horiz(curr_chunk.data, cfg.d_chan, cfg.dt*cfg.dt_decim_fac)
        plt.title(curr_chunk.filename)
        plt.show()
        if 'FORGE_78-32_iDASv3-P11_UTC190426064853.sgy' in curr_chunk.filename:
            saved_data = curr_chunk.data[:,4500:5500]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 15>()
#      12 data_iter = stream.DataIterator(proc_steps=cfg.proc_steps, folder_name=cfg.data_path,
#      13                                     db_name=cfg.events_db_name, output_overlap=cfg.overlap_samples)
#      14 plt.close('all')
# ---> 15 for curr_chunk in data_iter:
#      16     if curr_chunk.check_validity():
#      17         plot_seismic_horiz(curr_chunk.data, cfg.d_chan, cfg.dt*cfg.dt_decim_fac)
#
# File ~\Documents\DAS\das-ml\continuous_data_handling\data_streaming.py:496, in DataIterator.__next__(self)
#     494     overlap_chunk.data = proc.clip(overlap_chunk.data, cfg.clip_perc)
#     495 if 'bandpass' in self.proc_steps:
# --> 496     overlap_chunk.data = proc.bpfilter(overlap_chunk.data, dt=cfg.dt, bp_low=cfg.bp_low,
#     497                                        bp_high=cfg.bp_high)
#     498 if 'lowpass' in self.proc_steps:
#     499     overlap_chunk.data = proc.lpfilter(overlap_chunk.data, dt=cfg.dt, cutoff=cfg.lp_cutoff)
#
# File ~\Documents\DAS\das-ml\continuous_data_handling\signal_processing.py:69, in bpfilter(data, dt, bp_low, bp_high, zero_phase)
#      67 b, a = signal.butter(N=4, Wn=[bp_low, bp_high], btype='bandpass', fs=1/dt)
#      68 if zero_phase:
# ---> 69     return np.float32(signal.filtfilt(b, a, data, axis=- 1, padtype='odd'))
#      70 else:
#      71     return np.float32(signal.filt(b, a, data, axis=- 1, padtype='odd'))
#
# KeyboardInterrupt:

# %% [markdown]
# You can see that for the second file, there's a pretty cool earthquake around 10 seconds!
# Let's zoom on it (after we saved the data). You can see that the pre-processing we applied here (defined in config_general.py, and includes median filtering, clipping, band-pass filtering, and trace-by-trace normalization) does a good job cleaning up the data. Downsampling by a factor of 4 does not hamper data quality.

# %%
def plot_seismic_horiz(data, dx, dt):
    nch, nt = data.shape
#     plt.figure(figsize=(8,5))
    plt.imshow(data, aspect='auto', cmap='seismic', extent=(0, (nt-1)*dt, (nch-1)*dx, 0))
    plt.ylabel('Depth (m)')
    plt.xlabel('Time (s)')

# %%
plt.figure(figsize=(20,15))
plot_seismic_horiz(saved_data, cfg.d_chan, cfg.dt*cfg.dt_decim_fac)
# plt.colorbar()
plt.savefig('test.png', dpi=600)
plt.show()

# %%
plt.savefig('test.png', dpi=1200)
